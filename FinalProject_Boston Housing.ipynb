# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Final Project: Boston Housing**

# %% [markdown]
# ##### Estimated time needed: **60** minutes

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %%
boston_df.isnull().sum()
# Out:
# Unnamed: 0    0
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# LSTAT         0
# MEDV          0
# dtype: int64

# %%
boston_df.duplicated().sum()
# Out:
# 0

# %%
pyplot.figure(figsize=(10,8))

# %%
sns.heatmap(boston_df.corr(), annot=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.heatmap(boston_df.corr(), annot=true)
#
# NameError: name 'true' is not defined

# %%
sns.heatmap(boston_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
pyplot.show()

# %%
sns.boxplot(y=boston_df['MEDV'])
# Out:
# <AxesSubplot:ylabel='MEDV'>

# %%
pyplot.title("MEDV Boxplot")
pyplot.show()

# %%
sns.countplot(x=boston_df['CHAS'])
pyplot.title("Charles River Houses")
pyplot.show()

# %%
boston_df['Age_Group'] =pd.cut(boston_df['Age',bins=3, labels=['Low','Med','High'])
# Out:
#   Cell In[17], line 1
#     boston_df['Age_Group'] =pd.cut(boston_df['Age',bins=3, labels=['Low','Med','High'])
#                                                                                       ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
boston_df['Age_Group'] =pd.cut(boston_df['Age'],bins=3, labels=['Low','Med','High'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ...

# %%
boston_df['AGE_GROUP'] =pd.cut(boston_df['AGE'], bins=3, labels=['Low','Med','High'])

# %%
sns.boxplot(x='AGE_GROUP', y='MEDV', data =boston_df)
# Out:
# <AxesSubplot:xlabel='AGE_GROUP', ylabel='MEDV'>

# %%
pyplot.show()

# %%
sns.scatterplot(x='NOX', y='INDUS', data =boston_df)
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='INDUS'>

# %%
sns.histoplot(boston_df['PTRATIO'], bins= 10)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.histoplot(boston_df['PTRATIO'], bins= 10)
#       2 pyplot.show()
#
# AttributeError: module 'seaborn' has no attribute 'histoplot'

# %%
sns.histplot(boston_df['PTRATIO'], bins= 10)
pyplot.show()

# %%
sns.histplot(boston_df['PTRATIO'], bins= 20)
pyplot.show()

# %%
river = boston_df[boston_df['CHAS']=1]
# Out:
#   Cell In[26], line 1
#     river = boston_df[boston_df['CHAS']=1]
#                       ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
river = boston_df[boston_df['CHAS']==1]

# %%
notriver = boston_df[boston_df['CHAS']=0]
# Out:
#   Cell In[28], line 1
#     notriver = boston_df[boston_df['CHAS']=0]
#                          ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
notriver = boston_df[boston_df['CHAS']==0]

# %%
scipy.stats.ttest_ind(river, notriver)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 scipy.stats.ttest_ind(river, notriver)
#
# File /lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:563, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     560     contains_nan = False  # behave like there are no NaNs
#     562 if vectorized and not contains_nan and not sentinel:
# --> 563     res = hypotest_fun_out(*samples, axis=axis, **kwds)
#     564     res = result_to_tuple(res)
#     565     res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File /lib/python3.12/site-packages/scipy/stats/_stats_py.py:7414, in ttest_ind(a, b, axis, equal_var, nan_policy, permutations, random_state, alternative, trim)
#    7412     old_errstate = np.geterr()
# ...

# %%
river = boston_df[boston_df['CHAS']==1]['MEDV']
not_river = boston_df[boston_df['CHAS']=0]['MEDV']
scipy.stats.levene(river, notriver)
